# %%
# !pip install youtube_dl
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 5.3 MB/s
# ...

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

###### Library ######

from __future__ import unicode_literals
from google.colab import output
import youtube_dl
import pandas as pd
from IPython.display import Audio
import shutil
import time
from __future__ import print_function
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account


#### Read Excel FIle and find youtube Link########
attempt = 1
def sa3():
     
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

    data = {
        'type': 'service_account',
        'project_id': 'enduring-smile-326213',
        'private_key_id': '65bc745bcec3282e2717c92404185751411222de',
        'private_key': '''-----BEGIN PRIVATE KEY-----

6+l9fU1cgoegofydk8RKOBfk
-----END PRIVATE KEY-----
''',
        'client_email': 'savan-681@enduring-smile-326213.iam.gserviceaccount.com',
        'client_id': '101977133819758285254',
        'auth_uri': 'https://accounts.google.com/o/oauth2/auth',
        'token_uri': 'https://oauth2.googleapis.com/token',
        'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs',
        'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/savan-681%40enduring-smile-326213.iam.gserviceaccount.com',
        }
    creds = None
    creds = service_account.Credentials.from_service_account_info(data,
            scopes=SCOPES)

    SAMPLE_SPREADSHEET_ID = \
        '1RKt_7CPYHzxcnZU6pqwvtvEwpoVyfUIHIsFZQb0eBdA'
    service = build('sheets', 'v4', credentials=creds)

    sheet = service.spreadsheets()

    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range='Sheet1!A2').execute()
    values = result.get('values', [])

    a = str(values)
    b = str(a[3:-3])
    c = len(a)

    if c == 2:
        wU = True
        time.sleep(1)
    else:
        wU = False

    if wU == True:
        sa6()
        time.sleep(10)  # waits 10s for preformance


###### After Song Play done Remove Link #######

def sa1():

    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

    data = {
        'type': 'service_account',
        'project_id': 'enduring-smile-326213',
        'private_key_id': '65bc745bcec3282e2717c92404185751411222de',
        'private_key': '''-----BEGIN PRIVATE KEY-----

6+l9fU1cgoegofydk8RKOBfk
-----END PRIVATE KEY-----
''',
        'client_email': 'savan-681@enduring-smile-326213.iam.gserviceaccount.com',
        'client_id': '101977133819758285254',
        'auth_uri': 'https://accounts.google.com/o/oauth2/auth',
        'token_uri': 'https://oauth2.googleapis.com/token',
        'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs',
        'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/savan-681%40enduring-smile-326213.iam.gserviceaccount.com',
        }
    creds = None
    creds = service_account.Credentials.from_service_account_info(data,
            scopes=SCOPES)

    SAMPLE_SPREADSHEET_ID = \
        '1RKt_7CPYHzxcnZU6pqwvtvEwpoVyfUIHIsFZQb0eBdA'
    service = build('sheets', 'v4', credentials=creds)

    sheet = service.spreadsheets()

  # request = sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID, range='Sheet1!A2')
  # response = request.execute()

    rb = {'requests': [{'deleteDimension': {'range': {
        'sheetId': '0',
        'dimension': 'ROWS',
        'startIndex': 1,
        'endIndex': 1,
        }}}, {'moveDimension': {'source': {
        'sheetId': '0',
        'dimension': 'ROWS',
        'startIndex': 2,
        'endIndex': 1000,
        }, 'destinationIndex': 1}}]}

    request = sheet.batchUpdate(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                body=rb).execute()


##### Take Link and Convert MP3 and play #########

def sa():
    
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

    data = {
        'type': 'service_account',
        'project_id': 'enduring-smile-326213',
        'private_key_id': '65bc745bcec3282e2717c92404185751411222de',
        'private_key': '''-----BEGIN PRIVATE KEY-----

6+l9fU1cgoegofydk8RKOBfk
-----END PRIVATE KEY-----
''',
        'client_email': 'savan-681@enduring-smile-326213.iam.gserviceaccount.com',
        'client_id': '101977133819758285254',
        'auth_uri': 'https://accounts.google.com/o/oauth2/auth',
        'token_uri': 'https://oauth2.googleapis.com/token',
        'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs',
        'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/savan-681%40enduring-smile-326213.iam.gserviceaccount.com',
        }
    creds = None
    creds = service_account.Credentials.from_service_account_info(data,
            scopes=SCOPES)

    SAMPLE_SPREADSHEET_ID = \
        '1RKt_7CPYHzxcnZU6pqwvtvEwpoVyfUIHIsFZQb0eBdA'
    service = build('sheets', 'v4', credentials=creds)

    sheet = service.spreadsheets()

    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range='Sheet1!A2').execute()
    values = result.get('values', [])

    a = str(values)
    b = str(a[3:-3])
    link = str(b)

    if 'youtube' or 'youtu.be' in link:
        pass
    else:

        # print(f'{link} This link is not a youtube Link')

        sa1()
        output.clear()
        sa6()

    global attempt
    while attempt < 3:
            
         
        try:
            name = 'content/drive/MyDrive/savan'

            ydl_opts = {'format': 'bestaudio/best',
                        'postprocessors': [{'key': 'FFmpegExtractAudio',
                        'preferredcodec': 'mp3', 'preferredquality': '320'
                        }], 'outtmpl': name + '.mp3'}

            with youtube_dl.YoutubeDL(ydl_opts) as ydl:

                meta = ydl.extract_info(link, download=False)
                ydl.cache.remove()
                ydl.download([link])
                er = meta['title']  # ### Video title
                rt = meta['duration']  # ### Video length in sec

            display(Audio('/content/content/drive/MyDrive/savan.mp3',
                    autoplay=True))  # #### play song
            time.sleep(rt + 7)  # #### wait until song finish

                
        except youtube_dl.DownloadError as error:
            # print('1')
            # print(attempt) 

            attempt+=1         
            # youtube-dl --rm-cache-dir
            time.sleep(10)
            
            output.clear()
            sa6()
            
                  
    else:
        sa1()
        # time.sleep(10)
        output.clear()
        attempt = 1

        sa6()
        

def sa2():
    shutil.rmtree('/content/content/drive')  # #### Remove Downloaded MP3 every time


def sa6():
    while True:
        sa3()
        
        sa()
        sa2()
        sa1()
        output.clear()


sa6()
# Out:
# [youtube] 9uDgJ9_H0gg: Downloading webpage
# Removing cache dir /root/.cache/youtube-dl ..
# [youtube] 9uDgJ9_H0gg: Downloading webpage
# [download] Destination: content/drive/MyDrive/savan.mp3
# [download] 100% of 548.00B in 00:00
# [ffmpeg] Post-process file content/drive/MyDrive/savan.mp3 exists, skipping
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# [youtube] 9uDgJ9_H0gg: Downloading webpage
# Removing cache dir /root/.cache/youtube-dl ..
# [youtube] 9uDgJ9_H0gg: Downloading webpage
# [download] content/drive/MyDrive/savan.mp3 has already been downloaded
# [download] 100% of 548.00B
# [ffmpeg] Post-process file content/drive/MyDrive/savan.mp3 exists, skipping
#                 <audio controls="controls" autoplay="autoplay">
# ...
